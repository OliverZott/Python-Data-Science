# %% [markdown]
# # Haushaltstagebuch Beispiel

# %%
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### Import Data & Refactor Index

# %%
# import data
file = "../../data/Out_In_Manager.xlsx"
df = pd.read_excel(file, index_col="Datum", parse_dates=True)


# refactor index
df.index = df.index.date
df
# Out:
#                  Konto           Kategorie  Unterkategorie  \
# 2022-06-09     Bargeld    Auto-/Fahrkosten             NaN
# 2022-06-08  Gurkokonto             Wohnen              NaN
# 2022-06-08     Bargeld  Lebensmittelkosten             NaN
# 2022-06-07     Bargeld         Restaurant              NaN
# 2022-06-04     Bargeld  Lebensmittelkosten             NaN
# ...                ...                 ...             ...
# 2021-08-09     Bargeld  Lebensmittelkosten             NaN
# 2021-08-09     Bargeld             Bildung             NaN
# 2021-08-08     Bargeld            Sonstige             NaN
# 2021-08-07     Bargeld  Lebensmittelkosten             NaN
# 2021-08-05     Bargeld            Sonstige             NaN
#
#                            Notiz     EUR Einnahmen/Ausgaben  Notiz.1  Betrag  \
# 2022-06-09             Ibk-Telfs    16.0            Ausgabe      NaN    16.0
# 2022-06-08                 Miete  1200.0            Ausgabe      NaN  1200.0
# ...

# %% [markdown]
# ## Check-out data

# %%
df.mon
df.columns
df.index
df.head()
df[["Konto", "Kategorie"]].value_counts()
# Out:
# Index(['Konto', 'Kategorie', 'Unterkategorie', 'Notiz', 'EUR',
#        'Einnahmen/Ausgaben', 'Notiz.1', 'Betrag', 'Währung', 'Konto.1'],
#       dtype='object')
# Index([2022-06-09, 2022-06-08, 2022-06-08, 2022-06-07, 2022-06-04, 2022-06-02,
#        2022-06-02, 2022-06-01, 2022-06-01, 2022-06-01,
#        ...
#        2021-08-17, 2021-08-16, 2021-08-12, 2021-08-11, 2021-08-11, 2021-08-09,
#        2021-08-09, 2021-08-08, 2021-08-07, 2021-08-05],
#       dtype='object', length=148)
#                  Konto           Kategorie  Unterkategorie              Notiz  \
# 2022-06-09     Bargeld    Auto-/Fahrkosten             NaN          Ibk-Telfs
# 2022-06-08  Gurkokonto             Wohnen              NaN              Miete
# 2022-06-08     Bargeld  Lebensmittelkosten             NaN                NaN
# 2022-06-07     Bargeld         Restaurant              NaN  Kickoff - Mai Tai
# 2022-06-04     Bargeld  Lebensmittelkosten             NaN                NaN
#
# ...

# %% [markdown]
# ## Group & Aggregate
# - Bargeld
# - Monatsweise ?!
# - was ist max, min
# - mean zu bestimmtem wert
# - tortendiagramm

# %% [markdown]
# ## Seaborn Plot-Analysis
# see 5_Exercise
#
#
# - tortendiagramm
