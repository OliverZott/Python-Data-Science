# %% [markdown]
# # Pandas build-in Data Visualization
#
# - Based on Matplotlib but included in Pandas for easier use.
# - Easier and faster to use then using matplotlib.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# !python -V
import sys
print(sys.executable)
# Out:
# Python 3.9.7
# /home/olli/miniconda3/envs/data_science/bin/python

# %%
df1 = pd.read_csv("Df1", index_col=0)
df2 = pd.read_csv("Df2")

df1.head()
df2.head()
df2.tail()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
#           a         b         c         d
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
# Pandas Histogram 

# adding plot style
plt.style.use('ggplot')


df1['A'].hist(bins=15)
# Out:
# <AxesSubplot:>

# %%
# Areaplot
df2.plot.area(alpha=0.6)
# Out:
# <AxesSubplot:>

# %%
# Barplot
df2.plot.bar(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
# Lineplot
df1.plot.line(figsize=(12,6))
#df1.plot.line(x=df1.index, y='B')
# Out:
# <AxesSubplot:>

# %%
df1['B'].plot.line(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
# Scatterplot
df1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm', figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
# Boxplot
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])
df
# Out:
#             a         b
# 0   -1.185881  0.485257
# 1   -0.548779  1.397395
# 2   -0.135553 -0.703688
# 3    0.333304  0.742961
# 4   -2.105045 -0.723596
# ..        ...       ...
# 995 -0.050352  1.959351
# 996  0.496887 -0.437331
# 997 -0.171754  0.515206
# 998 -0.190288 -0.895424
# 999 -0.086283  1.277472
#
# [1000 rows x 2 columns]

# %%
# Hexaplot
df.plot.hexbin(x='a', y='b', gridsize =25, figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
# Kernel density estimation
df2.plot.density(figsize=(12,8))
# Out:
# <AxesSubplot:ylabel='Density'>
