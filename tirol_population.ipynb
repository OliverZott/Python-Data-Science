# %% [markdown]
# # Population Change

# %%
import sys
import openpyxl
import pandas as pd
import seaborn as sns

# %matplotlib inline

# !python -V
print(sys.executable)
# Out:
# Python 3.9.6
# C:\Users\HAL9000\anaconda3\envs\data_science\python.exe

# %% [markdown]
# ## 1. Import Data

# %% [markdown]
# ### .xlsx

# %%
try:
    pop = openpyxl.load_workbook('bev_meld.xlsx')
except IOError as err:
    print(f'Error: {e}')

sheet = pop['Gemeinden']
sheet
# Out:
# C:\Users\HAL9000\anaconda3\envs\data_science\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
# <Worksheet "Gemeinden">

# %% [markdown]
# ### .csv

# %%
# Import data

try: 
    population = pd.read_csv('bev_meld.csv', skiprows=2, encoding='latin1')
except Exception as err:
    print(f'Errortype: {err.__class__.__name__}')
    print(f'Error: {err}')
    raise err
    
population.drop([0,0], inplace=True)

display(population.head())
print('----------------------------------------------------------------------------------------------')
display(population.dtypes.head())
print('----------------------------------------------------------------------------------------------')
print(type(pop))
print('----------------------------------------------------------------------------------------------')
print(population.columns)
print('----------------------------------------------------------------------------------------------')
print(population.info())
# Out:
#   Bezirk    Gemnr         Gemeinde     1993     1994     1995     1996  \
# 1      I  70101.0       Innsbruck   111.305  112.174  112.759  109.150
# 2     IM  70201.0  Arzl im Pitztal    2.492    2.669    2.693    2.737
# 3     IM  70202.0          Haiming    3.625    3.701    3.677    3.725
# 4     IM  70203.0             Imst    7.925    8.145    7.984    8.071
# 5     IM  70204.0       Imsterberg  683.000  687.000  703.000  706.000
#
#       1997     1998     1999  ...     2012     2013     2014     2015  \
# 1  109.763  110.454  110.997  ...  119.846  122.458  124.579  126.965
# 2    2.738    2.729    2.779  ...    2.989    2.983    3.030    3.039
# 3    3.741    3.739    3.768  ...    4.457    4.444    4.474    4.528
# 4    8.268    8.399    8.542  ...    9.504    9.552    9.661    9.827
# 5  709.000  722.000  734.000  ...  743.000  761.000  757.000  774.000
#
#       2016     2017     2018     2019     2020     2021
# 1  131.009  132.236  132.493  132.110  131.961  131.059
# ...

# %%
# Group data
bezirk = population.groupby('Bezirk')
display(bezirk.head(2))
display(bezirk.mean())
# Out:
#     Bezirk    Gemnr              Gemeinde     1993     1994     1995     1996  \
# 1        I  70101.0            Innsbruck   111.305  112.174  112.759  109.150
# 2       IM  70201.0       Arzl im Pitztal    2.492    2.669    2.693    2.737
# 3       IM  70202.0               Haiming    3.625    3.701    3.677    3.725
# 26      IL  70301.0                 Absam    6.418    6.184    6.206    6.179
# 27      IL  70302.0               Aldrans    1.823    1.831    1.885    1.884
# 91      KB  70401.0  Aurach bei Kitzbühel    1.098    1.131    1.153    1.169
# 92      KB  70402.0       Brixen im Thale    2.389    2.412    2.463    2.514
# 111     KU  70501.0               Alpbach    2.295    2.299    2.332    2.339
# 112     KU  70502.0                Angath  750.000  754.000  756.000  725.000
# 141     LA  70601.0                Faggen  251.000  269.000  260.000  258.000
# 142     LA  70602.0               Fendels  212.000  223.000  229.000  225.000
# ...

# %% [markdown]
# # Telfs

# %% [markdown]
# ## Version 1

# %%
population.head()
df_prepared = population.drop(['Bezirk', 'Gemnr'], axis = 1).set_index('Gemeinde')
#df_prepared = population.drop(['Bezirk', 'Gemnr'], axis = 1)
display(df_prepared)
# df_telfs = df_prepared.loc[df_prepared['Gemeinde'] == 'Telfs'].T
df_telfs = df_prepared.loc['Telfs']
display(df_telfs)


print('-------------------------------------------------------------')
# Make df from series
df_telfs.to_frame().info()
print('-------------------------------------------------------------')
df_telfs.dtypes
# Out:
#                     1993     1994     1995     1996     1997     1998  \
# Gemeinde
# Innsbruck        111.305  112.174  112.759  109.150  109.763  110.454
# Arzl im Pitztal    2.492    2.669    2.693    2.737    2.738    2.729
# Haiming            3.625    3.701    3.677    3.725    3.741    3.739
# Imst               7.925    8.145    7.984    8.071    8.268    8.399
# Imsterberg       683.000  687.000  703.000  706.000  709.000  722.000
# ...                  ...      ...      ...      ...      ...      ...
# Weer               1.329    1.347    1.286    1.428    1.403    1.344
# Weerberg           2.019    2.065    2.116    2.158    2.181    2.195
# Wiesing            1.633    1.684    1.686    1.701    1.697    1.708
# Zell am Ziller     1.934    1.928    1.957    1.974    2.000    1.946
# Zellberg         666.000  673.000  697.000  700.000  700.000  698.000
#
#                     1999     2000     2001     2002  ...     2012     2013  \
# ...

# %% [markdown]
# ## Version 2

# %%
display(population.head())

display(population.T.head())
# Out:
#   Bezirk    Gemnr         Gemeinde     1993     1994     1995     1996  \
# 1      I  70101.0       Innsbruck   111.305  112.174  112.759  109.150
# 2     IM  70201.0  Arzl im Pitztal    2.492    2.669    2.693    2.737
# 3     IM  70202.0          Haiming    3.625    3.701    3.677    3.725
# 4     IM  70203.0             Imst    7.925    8.145    7.984    8.071
# 5     IM  70204.0       Imsterberg  683.000  687.000  703.000  706.000
#
#       1997     1998     1999  ...     2012     2013     2014     2015  \
# 1  109.763  110.454  110.997  ...  119.846  122.458  124.579  126.965
# 2    2.738    2.729    2.779  ...    2.989    2.983    3.030    3.039
# 3    3.741    3.739    3.768  ...    4.457    4.444    4.474    4.528
# 4    8.268    8.399    8.542  ...    9.504    9.552    9.661    9.827
# 5  709.000  722.000  734.000  ...  743.000  761.000  757.000  774.000
#
#       2016     2017     2018     2019     2020     2021
# 1  131.009  132.236  132.493  132.110  131.961  131.059
# ...
